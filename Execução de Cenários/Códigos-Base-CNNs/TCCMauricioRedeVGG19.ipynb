# %% [markdown]
# # Classificação de Imagens de 38 classes de plantas e tipos de doenças, com Transfer Learning
# #### Objetivo: Analisar algumas redes com transfer learning e comparar os resultados, com base na variação de ajustes relacionados a parâmetros de early stop, early rate, camada dropout, camada BatchNormalize e Batchsize.
# #### Após análises dos dados de cada uma das 38 classes de imagens e por questão de performance, na execução limitada de processamento, a opção foi por utilizar somente 04 classes de status das condições de folhas de Uva, sendo que uma delas não continha imangens, sendo assim essa descartada.
#
#
# ##### Classes Consideradas:
# ###### Grape___Black_rot
# ###### Grape___Esca_(Black_Measles)
# ###### Grape___healthy

# %% [markdown]
# ## Legenda:
# #### Localização da base de dados no Kaggle: https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset
# #### Base de dados de treino (trainpath): Já separada pelo autor da base de dados, em localização específica no Kaggle.
# #### base de dados de validação (validpath): Já separada pelo autor da base de dados, em localização específica no Kaggle.
# ## Consultas:
# ##### https://keras.io/applications/
# ##### https://keras.io/api/applications/vgg/
# ##### https://www.tensorflow.org/tutorials/load_data/images
# ##### https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
# ##### https://keras.io/api/data_loading/

# %% [markdown]
# ## Leitura do local da base de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
workdir_path = '/content/drive/MyDrive/TrabalhoFinal/DadosTCC/archive' #MODIFICAR!!! #Caminho para o seu workspace
os.chdir(workdir_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.path.abspath(os.getcwd())
# Out:
# '/content/drive/MyDrive/TrabalhoFinal/DadosTCC/archive'

# %%
# Base de imagens para treino com total de xx imagens (classes de tipos de platas)
trainpath = workdir_path + '/classeuva/Train'

# Base de imagens para validação com total de xx imagens (classes de tipos de platas)
validpath = workdir_path + '/classeuva/Valid'

# Base de imagens para validação com total de xx imagens (classes de tipos de platas)
testpath = workdir_path + '/classeuva/Test'

# %% [markdown]
# ## Leitura de Bibliotecas

# %%
# !pip install keras_tqdm
import numpy as np
import keras as ks
import tensorflow as tf
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input, decode_predictions
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import *
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential, Model,load_model
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import os
import tensorflow_datasets as tfds
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from PIL import Image
# from keras.preprocessing.image import array_to_img, img_to_array, load_img
# from keras.applications.vgg16 import preprocess_input
from keras import losses
from tensorflow.keras.optimizers import RMSprop
from keras_tqdm import TQDMNotebookCallback
from random import randint
import matplotlib.pylab as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_tqdm in /usr/local/lib/python3.8/dist-packages (2.0.1)
# Requirement already satisfied: Keras in /usr/local/lib/python3.8/dist-packages (from keras_tqdm) (2.11.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from keras_tqdm) (4.64.1)

# %% [markdown]
# ## Contagem das classes de treino

# %%
# Contar as imagens em cada pasta. Uma pasta = uma classe de planta

count=0
nomeplantas=[]
totalimagens=[]
for i in os.listdir(trainpath):
  count+=1
  nomeplantas.append(i)
  
  images_path=os.listdir(trainpath+"/"+i)
  totalimagens.append(len(images_path))

# %%
# Total de Classes de Plantas
len(nomeplantas)
# Out:
# 3

# %% [markdown]
# ## Contagem das classes de validação

# %%
# Contar as imagens em cada pasta. Uma pasta = uma classe de planta

count=0
nomeplantas=[]
totalimagens=[]
for i in os.listdir(validpath):
  count+=1
  nomeplantas.append(i)
  
  images_path=os.listdir(validpath+"/"+i)
  totalimagens.append(len(images_path))

# %%
# Total de Classes de Plantas
len(nomeplantas)
# Out:
# 3

# %% [markdown]
# ## Tratar e  Carregar a Base de Treino
# ##### Ref: Como carregar imagens no Keras:
# https://www.tensorflow.org/tutorials/load_data/images
# ##### A documentação da função que usa para carregar os dados (detalhes dos parâmetros):
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

# %%
# A carga da imagem é feita em lotes o tamanho de lote ("batch_size") de 32 imagens
batch_size = 32
# altura da imagem
img_height = 224
# largura da imagem
img_width = 224

# %%
# usar a função para carregar as imagens:
# https://www.tensorflow.org/tutorials/load_data/images
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

train_data = tf.keras.utils.image_dataset_from_directory(   # função para carregar imagens de treino
  trainpath,                                                # caminho onde estão as imagens de treino (diretório "raiz")
  labels='inferred',                                        
  label_mode='categorical',                                          
  image_size=(img_height, img_width),                       # largura e altura
  batch_size=batch_size)                                    # tamanho do lote
# Out:
# Found 4659 files belonging to 3 classes.

# %%
# verifica o nome das classes (são 38 pastas, cada pasta é uma classe)
train_data.class_names
# Out:
# ['Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy']

# %%
# visualizar o tipo de objeto retornado
train_data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# loop para ver a dimensão da imagem:
# 32 classes (pastas)
# 250 largura
# 250 altura
# 3 canais
# obs: Um break para evitar de percorrer todas as imagens
for image_batch, labels_batch in train_data:
  print(image_batch.shape)
  break
# Out:
# (32, 224, 224, 3)

# %%
# Normalizar as imagens de treino para estabelecer uma variação de valores entre [0..1]. Camada específica para isso.
# Fonte: Documentação Keras

normalization_layer = tf.keras.layers.Rescaling(1./255)
train_data_normalized = train_data.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(train_data_normalized))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 0.0 0.9599035

# %%
# Analisa o resultado da normalização da Base de Treino
for image_batch, labels_batch in train_data_normalized:
  print(image_batch.shape)
  break
# Out:
# (32, 224, 224, 3)

# %%
# Analisa o resultado da normalização da Base de Treino - Formato
train_data_normalized
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# Analisa o resultado da normalização da Base de Treino - Matriz EGB
image_batch[5]
# Out:
# <tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
# array([[[0.78517413, 0.7655663 , 0.78125256],
#         [0.7604042 , 0.7407964 , 0.75648266],
#         [0.7488396 , 0.7292318 , 0.74491805],
#         ...,
#         [0.7583041 , 0.7347747 , 0.750461  ],
#         [0.69311655, 0.66958714, 0.6852734 ],
#         [0.73339456, 0.70986515, 0.7255514 ]],
#
#        [[0.7657263 , 0.7461185 , 0.76180476],
#         [0.7493798 , 0.729772  , 0.74545825],
#         [0.7496199 , 0.73001206, 0.74569833],
#         ...,
#         [0.6158857 , 0.59235626, 0.60804254],
#         [0.6400765 , 0.6165471 , 0.6322334 ],
#         [0.6467186 , 0.6231892 , 0.6388755 ]],
#
#        [[0.75622255, 0.7366147 , 0.752301  ],
#         [0.75328135, 0.7336735 , 0.7493598 ],
#         [0.76386553, 0.7442577 , 0.75994396],
#         ...,
#         [0.69697946, 0.67345005, 0.6891363 ],
#         [0.71026415, 0.68673474, 0.702421  ],
#         [0.791118  , 0.7675886 , 0.7832749 ]],
#
#        ...,
#
#        [[0.6249699 , 0.5896758 , 0.6092836 ],
#         [0.61212474, 0.5768306 , 0.59643847],
#         [0.64922005, 0.61392593, 0.6335338 ],
#         ...,
#         [0.40964264, 0.3782701 , 0.37042695],
#         [0.36460543, 0.33323288, 0.32538974],
#         [0.3564628 , 0.32509026, 0.31724712]],
#
#        [[0.59485775, 0.55956364, 0.5791715 ],
#         [0.6056223 , 0.5703282 , 0.589936  ],
#         [0.6622049 , 0.6269108 , 0.64651865],
#         ...,
#         [0.3790108 , 0.34763825, 0.3397951 ],
#         [0.3415564 , 0.31018385, 0.30234072],
#         [0.34273705, 0.3113645 , 0.30352136]],
#
#        [[0.5593432 , 0.5240491 , 0.54365695],
#         [0.6547429 , 0.6194488 , 0.6390566 ],
#         [0.66924787, 0.63395375, 0.6535616 ],
#         ...,
#         [0.3932971 , 0.36192456, 0.35408142],
#         [0.33363307, 0.3022605 , 0.29441735],
#         [0.28885403, 0.2574815 , 0.24963833]]], dtype=float32)>

# %% [markdown]
# ## Tratar e  Carregar a Base de Validação
# ## Ref: Como carregar imagens no Keras:
# https://www.tensorflow.org/tutorials/load_data/images
# ## A documentação da função que usa para carregar os dados (detalhes dos parâmetros):
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

# %%
# A carga da imagem é feita em lotes o tamanho de lote ("batch_size") de 32 imagens
batch_size = 32
# altura da imagem
img_height = 224
# largura da imagem
img_width = 224

# %%
# usar a função para carregar as imagens:
# https://www.tensorflow.org/tutorials/load_data/images
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

valid_data = tf.keras.utils.image_dataset_from_directory(   # função para carregar imagens de validação
  validpath,                                                # caminho onde estão as imagens de vaçidção (diretório "raiz")
  labels='inferred',                                        
  label_mode='categorical',                                 
  image_size=(img_height, img_width),                       # largura e altura
  batch_size=batch_size)                                    # tamanho do lote
# Out:
# Found 1169 files belonging to 3 classes.

# %%
# verifica o nome das classes (são 38 pastas, cada pasta é uma classe)
valid_data.class_names
# Out:
# ['Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy']

# %%
# visualizar o tipo de objeto retornado
valid_data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# loop para ver a dimensão da imagem:
# 32 classes (pastas)
# 250 largura
# 250 altura
# 3 canais
# obs: Um break para evitar de percorrer todas as imagens
for image_batch, labels_batch in valid_data:
  print(image_batch.shape)
  break
# Out:
# (32, 224, 224, 3)

# %%
# Normalizar as imagens de validação para estabelecer uma variação de valores entre [0..1]. Camada específica para isso.
# Fonte: Documentação Keras

normalization_layer = tf.keras.layers.Rescaling(1./255)
valid_data_normalized = valid_data.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(valid_data_normalized))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.994398

# %%
# Analisa o resultado da normalização da Base de Validação
for image_batch, labels_batch in valid_data_normalized:
  print(image_batch.shape)
  break
# Out:
# (32, 224, 224, 3)

# %%
# Analisa o resultado da normalização da Base de Validação - Formato
valid_data_normalized
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# Analisa o resultado da normalização da Base de Validação - Matriz EGB
image_batch[2]
# Out:
# <tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
# array([[[0.7044618 , 0.684854  , 0.67308927],
#         [0.665066  , 0.64545816, 0.63369346],
#         [0.62773114, 0.6081233 , 0.5963586 ],
#         ...,
#         [0.621388  , 0.5900155 , 0.57825077],
#         [0.59075624, 0.5593837 , 0.547619  ],
#         [0.6555435 , 0.62417096, 0.61240625]],
#
#        [[0.6767908 , 0.65718293, 0.6454182 ],
#         [0.7552021 , 0.7355943 , 0.72382957],
#         [0.6917568 , 0.67214894, 0.66038424],
#         ...,
#         [0.60690224, 0.57552963, 0.5637649 ],
#         [0.5764705 , 0.54509795, 0.53333324],
#         [0.6238305 , 0.59245795, 0.58069324]],
#
#        [[0.6950581 , 0.67545027, 0.66368556],
#         [0.7366347 , 0.7170268 , 0.7052621 ],
#         [0.6991397 , 0.6795318 , 0.6677671 ],
#         ...,
#         [0.6088833 , 0.5775108 , 0.56574607],
#         [0.5879551 , 0.55658257, 0.54481786],
#         [0.6119053 , 0.5805327 , 0.568768  ]],
#
#        ...,
#
#        [[0.72957164, 0.7256501 , 0.7452579 ],
#         [0.7243097 , 0.7203881 , 0.73999596],
#         [0.7236895 , 0.7197679 , 0.73937577],
#         ...,
#         [0.5846535 , 0.57681036, 0.5964182 ],
#         [0.57985175, 0.5720086 , 0.59161645],
#         [0.5818926 , 0.5740495 , 0.5936574 ]],
#
#        [[0.71848744, 0.7145658 , 0.7341737 ],
#         [0.71932775, 0.7154062 , 0.735014  ],
#         [0.7221089 , 0.71818733, 0.7377952 ],
#         ...,
#         [0.5642056 , 0.55636245, 0.5759703 ],
#         [0.5681473 , 0.56030416, 0.579912  ],
#         [0.5788318 , 0.57098866, 0.5905965 ]],
#
#        [[0.7280515 , 0.7241299 , 0.74373776],
#         [0.72134864, 0.7174271 , 0.7370349 ],
#         [0.7228693 , 0.7189477 , 0.73855555],
#         ...,
#         [0.57873195, 0.5708888 , 0.59049666],
#         [0.5973796 , 0.5895365 , 0.60914433],
#         [0.6157073 , 0.60786414, 0.627472  ]]], dtype=float32)>

# %% [markdown]
# ## Resumo Leitura de Imagens
# ##### 53655 .. 80% testes, 13414 .. 20% validação e 67.069 total de imagens

# %% [markdown]
# ## Modelo de Classificação VGG19 sem Transfer Learning e Data Augmentation
# ##### Analisar a resposta da classificação

# %%
pip install tf-explain
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tf-explain
#   Downloading tf_explain-0.3.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 5.4 MB/s eta 0:00:00
# Installing collected packages: tf-explain
# Successfully installed tf-explain-0.3.1

# %%
## Código consultado em https://medium.com/analytics-vidhya/image-recognition-using-pre-trained-xception-model-in-5-steps-96ac858f4206

# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
# from tensorflow.keras.optmizers import Adam
# from tensorflow.keras.losses import CategoricalCrossentropy
# import numpy as np

model = tf.keras.applications.VGG19(weights='imagenet', input_shape=(img_height,img_width,3))

# Carrega uma imagem de uma classe (Treino) para verificar a predição nessa Rede, nessas condições.
img = image.load_img(trainpath+"/Grape___healthy/ac753212-e6d7-44b9-9722-4413a7418ab3___Mt.N.V_HL 6178_180deg.JPG", target_size=(img_height,img_width,3))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=4)[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574710816/574710816 [==============================] - 5s 0us/step
# 1/1 [==============================] - 11s 11s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n03991062', 'pot', 0.2972955), ('n12768682', 'buckeye', 0.10490957), ('n04522168', 'vase', 0.08454256), ('n12267677', 'acorn', 0.04454502)]

# %%
# Avaliação da assertividade para a classe Tomato___Tomato_mosaic_virus da base de treino
import matplotlib.pylab as plt
plt.imshow(img)

# %% [markdown]
# Modelo nessa condição não obteve sucesso na identificação de uma imagem de uma classe. O que era previsto somente comprovando a necessidade de treinar um modelo aplicando Transfer Learning.

# %%
# Visualização das Camadas do Modelo VGG19 sem Transfer Learning e Data Augmentation
model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Analisa Camadas VGG19 Truncada

# %%
base_model_tf=tf.keras.applications.VGG19(weights='imagenet', classes=3, input_shape=(img_height,img_width,3), include_top=False)

#Model building
base_model_tf.trainable=False

base_model_tf.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
## API Keras https://keras.io/guides/functional_api/
## https://keras.io/guides/sequential_model/

# %% [markdown]
# ## Modelo VGG19 Base para Aplicar Transfer Learning

# %%
# Modelo Truncado:
modelo_base = tf.keras.applications.VGG19(weights='imagenet', classes=3, input_shape=(img_height,img_width,3), include_top=False)
# "Congelar" as camadas superiores (manter os pesos):
modelo_base.trainable=False
modelo_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ## Modelo VGG19 Truncado + Camada Dense
#
# *   Aproveitar a base de conhecimento VGG19 (Imagenet) e seus pesos
# *   Treinar essa base adicionando as novas Classes de Treino das Imagens Coletadas

# %%
# from tensorflow.keras.layers import Flatten
sh=Input(shape=(img_height,img_width,3)) # Formato de entrada imagem
conv=tf.cast(sh,tf.float32) 

modelo_dense_1=modelo_base(conv,training=False) #
modelo_dense_1=GlobalAveragePooling2D()(modelo_dense_1)
modelo_dense_1=Dropout(0.2)(modelo_dense_1)
modelo_dense_1=ks.layers.BatchNormalization(axis=1, momentum=0.99, epsilon=0.001)(modelo_dense_1)
modelo_dense_1=Dense(128,activation='relu')(modelo_dense_1)
modelo_dense_1=Dense(64,activation='relu')(modelo_dense_1)
modelo_dense_1=Dense(3,activation='softmax')(modelo_dense_1)

from keras.models import Model
modelo_final_1=Model(inputs=sh,outputs=modelo_dense_1)
modelo_final_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.cast (TFOpLambda)        (None, 224, 224, 3)       0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 20,100,547
# Trainable params: 75,139
# Non-trainable params: 20,025,408
# _________________________________________________________________

# %%
modelo_final_1.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7fdbb772ed30>,
#  <keras.layers.core.tf_op_layer.TFOpLambda at 0x7fdbb772ed00>,
#  <keras.engine.functional.Functional at 0x7fdbb775f580>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fdbb772ecd0>,
#  <keras.layers.regularization.dropout.Dropout at 0x7fdbb775ffd0>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7fdbb774ddc0>,
#  <keras.layers.core.dense.Dense at 0x7fdbb76d9ee0>,
#  <keras.layers.core.dense.Dense at 0x7fdbb7735250>,
#  <keras.layers.core.dense.Dense at 0x7fdbb76e4430>]

# %%
# Definie as métricas
earlystp=EarlyStopping(patience=25, monitor='val_loss') # Evitar um Overfiting do Modelo
metrics = ['accuracy',Precision(),Recall(), AUC()]

# %%
# Compila o Modelo
modelo_final_1.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01),metrics=metrics)

# %%
# Processa o modelo com Transfer Learning usando a base de imagens de Treino Normalizada e a base de Validação Normalizada
modelo_final_1_Hist = modelo_final_1.fit(train_data_normalized,validation_data=valid_data_normalized,epochs=200,verbose=1,callbacks=[earlystp])
# Out:
# Epoch 1/200
# 146/146 [==============================] - 581s 4s/step - loss: 0.2913 - accuracy: 0.8843 - precision: 0.8899 - recall: 0.8777 - auc: 0.9767 - val_loss: 0.4911 - val_accuracy: 0.8956 - val_precision: 0.9893 - val_recall: 0.7109 - val_auc: 0.9860
# Epoch 2/200
# 146/146 [==============================] - 31s 209ms/step - loss: 0.2132 - accuracy: 0.9169 - precision: 0.9207 - recall: 0.9144 - auc: 0.9864 - val_loss: 0.2995 - val_accuracy: 0.9435 - val_precision: 0.9716 - val_recall: 0.8794 - val_auc: 0.9934
# Epoch 3/200
# 146/146 [==============================] - 31s 204ms/step - loss: 0.1814 - accuracy: 0.9266 - precision: 0.9286 - recall: 0.9236 - auc: 0.9901 - val_loss: 0.2187 - val_accuracy: 0.9093 - val_precision: 0.9149 - val_recall: 0.9008 - val_auc: 0.9863
# Epoch 4/200
# 146/146 [==============================] - 31s 208ms/step - loss: 0.1798 - accuracy: 0.9337 - precision: 0.9351 - recall: 0.9309 - auc: 0.9903 - val_loss: 0.1493 - val_accuracy: 0.9427 - val_precision: 0.9427 - val_recall: 0.9427 - val_auc: 0.9941
# Epoch 5/200
# 146/146 [==============================] - 34s 231ms/step - loss: 0.1682 - accuracy: 0.9369 - precision: 0.9400 - recall: 0.9356 - auc: 0.9911 - val_loss: 0.1078 - val_accuracy: 0.9632 - val_precision: 0.9632 - val_recall: 0.9615 - val_auc: 0.9971
# Epoch 6/200
# 146/146 [==============================] - 31s 207ms/step - loss: 0.1757 - accuracy: 0.9350 - precision: 0.9367 - recall: 0.9332 - auc: 0.9910 - val_loss: 0.0857 - val_accuracy: 0.9683 - val_precision: 0.9692 - val_recall: 0.9683 - val_auc: 0.9979
# Epoch 7/200
# 146/146 [==============================] - 30s 204ms/step - loss: 0.1450 - accuracy: 0.9405 - precision: 0.9429 - recall: 0.9388 - auc: 0.9933 - val_loss: 0.1025 - val_accuracy: 0.9632 - val_precision: 0.9632 - val_recall: 0.9632 - val_auc: 0.9969
# Epoch 8/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.1411 - accuracy: 0.9444 - precision: 0.9463 - recall: 0.9423 - auc: 0.9934 - val_loss: 0.1059 - val_accuracy: 0.9589 - val_precision: 0.9589 - val_recall: 0.9589 - val_auc: 0.9966
# Epoch 9/200
# 146/146 [==============================] - 30s 205ms/step - loss: 0.1211 - accuracy: 0.9487 - precision: 0.9495 - recall: 0.9481 - auc: 0.9953 - val_loss: 0.0937 - val_accuracy: 0.9624 - val_precision: 0.9624 - val_recall: 0.9624 - val_auc: 0.9970
# Epoch 10/200
# 146/146 [==============================] - 31s 205ms/step - loss: 0.1418 - accuracy: 0.9476 - precision: 0.9492 - recall: 0.9463 - auc: 0.9933 - val_loss: 0.1598 - val_accuracy: 0.9607 - val_precision: 0.9607 - val_recall: 0.9607 - val_auc: 0.9938
# Epoch 11/200
# 146/146 [==============================] - 31s 206ms/step - loss: 0.1274 - accuracy: 0.9489 - precision: 0.9517 - recall: 0.9472 - auc: 0.9948 - val_loss: 0.0885 - val_accuracy: 0.9649 - val_precision: 0.9649 - val_recall: 0.9649 - val_auc: 0.9976
# Epoch 12/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.1146 - accuracy: 0.9549 - precision: 0.9561 - recall: 0.9536 - auc: 0.9955 - val_loss: 0.1116 - val_accuracy: 0.9547 - val_precision: 0.9555 - val_recall: 0.9547 - val_auc: 0.9962
# Epoch 13/200
# 146/146 [==============================] - 34s 231ms/step - loss: 0.1166 - accuracy: 0.9616 - precision: 0.9620 - recall: 0.9614 - auc: 0.9952 - val_loss: 0.0900 - val_accuracy: 0.9649 - val_precision: 0.9649 - val_recall: 0.9649 - val_auc: 0.9970
# Epoch 14/200
# 146/146 [==============================] - 34s 232ms/step - loss: 0.1164 - accuracy: 0.9609 - precision: 0.9615 - recall: 0.9605 - auc: 0.9953 - val_loss: 0.1018 - val_accuracy: 0.9581 - val_precision: 0.9589 - val_recall: 0.9581 - val_auc: 0.9970
# Epoch 15/200
# 146/146 [==============================] - 34s 232ms/step - loss: 0.1100 - accuracy: 0.9631 - precision: 0.9634 - recall: 0.9618 - auc: 0.9955 - val_loss: 0.0919 - val_accuracy: 0.9683 - val_precision: 0.9708 - val_recall: 0.9683 - val_auc: 0.9971
# Epoch 16/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.1173 - accuracy: 0.9573 - precision: 0.9579 - recall: 0.9564 - auc: 0.9952 - val_loss: 0.0850 - val_accuracy: 0.9692 - val_precision: 0.9692 - val_recall: 0.9692 - val_auc: 0.9973
# Epoch 17/200
# 146/146 [==============================] - 34s 231ms/step - loss: 0.1006 - accuracy: 0.9590 - precision: 0.9592 - recall: 0.9586 - auc: 0.9964 - val_loss: 0.1014 - val_accuracy: 0.9641 - val_precision: 0.9640 - val_recall: 0.9632 - val_auc: 0.9968
# Epoch 18/200
# 146/146 [==============================] - 34s 232ms/step - loss: 0.1136 - accuracy: 0.9601 - precision: 0.9607 - recall: 0.9590 - auc: 0.9948 - val_loss: 0.0837 - val_accuracy: 0.9683 - val_precision: 0.9692 - val_recall: 0.9683 - val_auc: 0.9979
# Epoch 19/200
# 146/146 [==============================] - 35s 231ms/step - loss: 0.0956 - accuracy: 0.9672 - precision: 0.9680 - recall: 0.9669 - auc: 0.9965 - val_loss: 0.0781 - val_accuracy: 0.9709 - val_precision: 0.9709 - val_recall: 0.9709 - val_auc: 0.9982
# Epoch 20/200
# 146/146 [==============================] - 31s 207ms/step - loss: 0.0921 - accuracy: 0.9661 - precision: 0.9663 - recall: 0.9659 - auc: 0.9969 - val_loss: 0.1057 - val_accuracy: 0.9581 - val_precision: 0.9581 - val_recall: 0.9581 - val_auc: 0.9967
# Epoch 21/200
# 146/146 [==============================] - 35s 233ms/step - loss: 0.1055 - accuracy: 0.9594 - precision: 0.9601 - recall: 0.9594 - auc: 0.9962 - val_loss: 0.1006 - val_accuracy: 0.9598 - val_precision: 0.9606 - val_recall: 0.9598 - val_auc: 0.9954
# Epoch 22/200
# 146/146 [==============================] - 31s 206ms/step - loss: 0.0978 - accuracy: 0.9682 - precision: 0.9682 - recall: 0.9680 - auc: 0.9958 - val_loss: 0.0933 - val_accuracy: 0.9649 - val_precision: 0.9649 - val_recall: 0.9649 - val_auc: 0.9968
# Epoch 23/200
# 146/146 [==============================] - 35s 234ms/step - loss: 0.0938 - accuracy: 0.9678 - precision: 0.9688 - recall: 0.9678 - auc: 0.9965 - val_loss: 0.1046 - val_accuracy: 0.9641 - val_precision: 0.9641 - val_recall: 0.9641 - val_auc: 0.9952
# Epoch 24/200
# 146/146 [==============================] - 30s 205ms/step - loss: 0.1124 - accuracy: 0.9648 - precision: 0.9658 - recall: 0.9633 - auc: 0.9959 - val_loss: 0.0924 - val_accuracy: 0.9675 - val_precision: 0.9683 - val_recall: 0.9675 - val_auc: 0.9959
# Epoch 25/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.0759 - accuracy: 0.9689 - precision: 0.9691 - recall: 0.9687 - auc: 0.9979 - val_loss: 0.1607 - val_accuracy: 0.9453 - val_precision: 0.9453 - val_recall: 0.9453 - val_auc: 0.9924
# Epoch 26/200
# 146/146 [==============================] - 30s 205ms/step - loss: 0.1083 - accuracy: 0.9633 - precision: 0.9641 - recall: 0.9620 - auc: 0.9959 - val_loss: 0.0955 - val_accuracy: 0.9641 - val_precision: 0.9641 - val_recall: 0.9641 - val_auc: 0.9963
# Epoch 27/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.1389 - accuracy: 0.9545 - precision: 0.9555 - recall: 0.9530 - auc: 0.9942 - val_loss: 0.0814 - val_accuracy: 0.9701 - val_precision: 0.9709 - val_recall: 0.9701 - val_auc: 0.9969
# Epoch 28/200
# 146/146 [==============================] - 34s 231ms/step - loss: 0.0780 - accuracy: 0.9693 - precision: 0.9701 - recall: 0.9691 - auc: 0.9978 - val_loss: 0.0967 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9960
# Epoch 29/200
# 146/146 [==============================] - 31s 206ms/step - loss: 0.0985 - accuracy: 0.9689 - precision: 0.9691 - recall: 0.9678 - auc: 0.9967 - val_loss: 0.1182 - val_accuracy: 0.9658 - val_precision: 0.9658 - val_recall: 0.9658 - val_auc: 0.9935
# Epoch 30/200
# 146/146 [==============================] - 34s 231ms/step - loss: 0.0894 - accuracy: 0.9657 - precision: 0.9663 - recall: 0.9648 - auc: 0.9970 - val_loss: 0.1056 - val_accuracy: 0.9641 - val_precision: 0.9641 - val_recall: 0.9641 - val_auc: 0.9954
# Epoch 31/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.0853 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9706 - auc: 0.9965 - val_loss: 0.0971 - val_accuracy: 0.9692 - val_precision: 0.9692 - val_recall: 0.9683 - val_auc: 0.9958
# Epoch 32/200
# 146/146 [==============================] - 31s 206ms/step - loss: 0.1010 - accuracy: 0.9648 - precision: 0.9656 - recall: 0.9644 - auc: 0.9961 - val_loss: 0.1022 - val_accuracy: 0.9666 - val_precision: 0.9666 - val_recall: 0.9666 - val_auc: 0.9964
# Epoch 33/200
# 146/146 [==============================] - 31s 207ms/step - loss: 0.0903 - accuracy: 0.9689 - precision: 0.9705 - recall: 0.9682 - auc: 0.9975 - val_loss: 0.0865 - val_accuracy: 0.9641 - val_precision: 0.9657 - val_recall: 0.9624 - val_auc: 0.9975
# Epoch 34/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.0876 - accuracy: 0.9700 - precision: 0.9704 - recall: 0.9695 - auc: 0.9967 - val_loss: 0.0998 - val_accuracy: 0.9641 - val_precision: 0.9666 - val_recall: 0.9641 - val_auc: 0.9967
# Epoch 35/200
# 146/146 [==============================] - 34s 232ms/step - loss: 0.0682 - accuracy: 0.9770 - precision: 0.9772 - recall: 0.9768 - auc: 0.9979 - val_loss: 0.0873 - val_accuracy: 0.9709 - val_precision: 0.9709 - val_recall: 0.9709 - val_auc: 0.9967
# Epoch 36/200
# 146/146 [==============================] - 31s 206ms/step - loss: 0.0707 - accuracy: 0.9751 - precision: 0.9755 - recall: 0.9749 - auc: 0.9979 - val_loss: 0.1003 - val_accuracy: 0.9624 - val_precision: 0.9624 - val_recall: 0.9624 - val_auc: 0.9961
# Epoch 37/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.0824 - accuracy: 0.9706 - precision: 0.9712 - recall: 0.9700 - auc: 0.9970 - val_loss: 0.1079 - val_accuracy: 0.9624 - val_precision: 0.9624 - val_recall: 0.9624 - val_auc: 0.9957
# Epoch 38/200
# 146/146 [==============================] - 30s 205ms/step - loss: 0.0763 - accuracy: 0.9721 - precision: 0.9725 - recall: 0.9712 - auc: 0.9977 - val_loss: 0.0911 - val_accuracy: 0.9735 - val_precision: 0.9735 - val_recall: 0.9735 - val_auc: 0.9950
# Epoch 39/200
# 146/146 [==============================] - 35s 233ms/step - loss: 0.0778 - accuracy: 0.9734 - precision: 0.9742 - recall: 0.9732 - auc: 0.9979 - val_loss: 0.1071 - val_accuracy: 0.9615 - val_precision: 0.9623 - val_recall: 0.9615 - val_auc: 0.9946
# Epoch 40/200
# 146/146 [==============================] - 34s 232ms/step - loss: 0.0880 - accuracy: 0.9723 - precision: 0.9733 - recall: 0.9715 - auc: 0.9967 - val_loss: 0.1475 - val_accuracy: 0.9607 - val_precision: 0.9623 - val_recall: 0.9598 - val_auc: 0.9905
# Epoch 41/200
# 146/146 [==============================] - 34s 232ms/step - loss: 0.0908 - accuracy: 0.9725 - precision: 0.9729 - recall: 0.9723 - auc: 0.9964 - val_loss: 0.1098 - val_accuracy: 0.9641 - val_precision: 0.9640 - val_recall: 0.9632 - val_auc: 0.9961
# Epoch 42/200
# 146/146 [==============================] - 34s 233ms/step - loss: 0.1010 - accuracy: 0.9678 - precision: 0.9682 - recall: 0.9674 - auc: 0.9962 - val_loss: 0.0912 - val_accuracy: 0.9692 - val_precision: 0.9725 - val_recall: 0.9675 - val_auc: 0.9976
# Epoch 43/200
# 146/146 [==============================] - 34s 232ms/step - loss: 0.0660 - accuracy: 0.9783 - precision: 0.9785 - recall: 0.9777 - auc: 0.9979 - val_loss: 0.1691 - val_accuracy: 0.9393 - val_precision: 0.9408 - val_recall: 0.9384 - val_auc: 0.9920
# Epoch 44/200
# 146/146 [==============================] - 31s 207ms/step - loss: 0.1050 - accuracy: 0.9661 - precision: 0.9671 - recall: 0.9661 - auc: 0.9963 - val_loss: 0.1041 - val_accuracy: 0.9530 - val_precision: 0.9538 - val_recall: 0.9530 - val_auc: 0.9967

# %% [markdown]
# ## Análise da VGG19 - Transfer Learning
# ##### Métricas:
# ###### Acurácia: Taxa de acerto do modelo - VP + VN / (VP+VN+FN+FP). Pode mascarar falso positivo e falso negativo.
# ###### Recall: Taxa de VP entre todas as classes positivas. Varia de 0 a 1 , quanto maior o valor melhor - VP / VP + FN
# ###### Precisão: Taxa de VP entre os valores Positivos Preditos. VP / VP+FP. Quanto menor a qtd de falsos alarmes melhor.
# ###### AUC: Relação com a curva ROC (Receiver Operating Characteristic). É a área sob a curva e é recomendada para comparar modelos diferentes. Varia entre 0 e 1 e quanto maior o valor melhor a classificação.

# %%
print(modelo_final_1_Hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'auc', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc'])

# %%
plt.plot(modelo_final_1_Hist.history['accuracy'])
plt.plot(modelo_final_1_Hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(modelo_final_1_Hist.history['loss'])
plt.plot(modelo_final_1_Hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(modelo_final_1_Hist.history['precision'])
plt.plot(modelo_final_1_Hist.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(modelo_final_1_Hist.history['recall'])
plt.plot(modelo_final_1_Hist.history['val_recall'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(modelo_final_1_Hist.history['auc'])
plt.plot(modelo_final_1_Hist.history['val_auc'])
plt.title('model auc')
plt.ylabel('auc')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()
