# %% [markdown]
# # Classificação de Imagens de 38 classes de plantas e tipos de doenças, com Transfer Learning
# #### Objetivo: Analisar algumas redes com transfer learning e comparar os resultados, com base na variação de ajustes relacionados a parâmetros de early stop, early rate, camada dropout, camada BatchNormalize e Batchsize.
# #### Após análises dos dados de cada uma das 38 classes de imagens e por questão de performance, na execução limitada de processamento, a opção foi por utilizar somente 04 classes de status das condições de folhas de Uva, sendo que uma delas não continha imangens, sendo assim essa descartada.
#
#
# ##### Classes Consideradas:
# ###### Grape___Black_rot
# ###### Grape___Esca_(Black_Measles)
# ###### Grape___healthy

# %% [markdown]
# ## Legenda:
# #### Localização da base de dados no Kaggle: https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset
# #### Base de dados de treino (trainpath): Já separada pelo autor da base de dados, em localização específica no Kaggle.
# #### base de dados de validação (validpath): Já separada pelo autor da base de dados, em localização específica no Kaggle.
# ## Consultas:
# ##### https://keras.io/applications/
# ##### https://keras.io/api/applications/vgg/
# ##### https://www.tensorflow.org/tutorials/load_data/images
# ##### https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
# ##### https://keras.io/api/data_loading/

# %% [markdown]
# ## Leitura do local da base de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
workdir_path = '/content/drive/MyDrive/TrabalhoFinal/DadosTCC/archive' #MODIFICAR!!! #Caminho para o seu workspace
os.chdir(workdir_path)
# Out:
# Mounted at /content/drive

# %%
os.path.abspath(os.getcwd())
# Out:
# '/content/drive/MyDrive/TrabalhoFinal/DadosTCC/archive'

# %%
# Base de imagens para treino com total de xx imagens (classes de tipos de platas)
trainpath = workdir_path + '/classeuva/Train'

# Base de imagens para validação com total de xx imagens (classes de tipos de platas)
validpath = workdir_path + '/classeuva/Valid'

# Base de imagens para testes com total de xx imagens (classes de tipos de platas)
testpath = workdir_path + '/classeuva/Test'

# %% [markdown]
# ## Leitura de Bibliotecas

# %%
# !pip install keras_tqdm
import numpy as np
import keras as ks
import tensorflow as tf
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input, decode_predictions
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import *
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential, Model,load_model
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import os
import tensorflow_datasets as tfds
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from PIL import Image
# from keras.preprocessing.image import array_to_img, img_to_array, load_img
# from keras.applications.vgg16 import preprocess_input
from keras import losses
from tensorflow.keras.optimizers import RMSprop
from keras_tqdm import TQDMNotebookCallback
from random import randint
import matplotlib.pylab as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_tqdm
#   Downloading keras_tqdm-2.0.1-py2.py3-none-any.whl (7.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from keras_tqdm) (4.64.1)
# Requirement already satisfied: Keras in /usr/local/lib/python3.8/dist-packages (from keras_tqdm) (2.11.0)
# Installing collected packages: keras_tqdm
# Successfully installed keras_tqdm-2.0.1

# %% [markdown]
# ## Contagem das classes de treino

# %%
# Contar as imagens em cada pasta. Uma pasta = uma classe de planta

count=0
nomeplantas=[]
totalimagens=[]
for i in os.listdir(trainpath):
  count+=1
  nomeplantas.append(i)
  
  images_path=os.listdir(trainpath+"/"+i)
  totalimagens.append(len(images_path))

# %%
# Total de Classes de Plantas
len(nomeplantas)
# Out:
# 3

# %% [markdown]
# ## Contagem das classes de validação

# %%
# Contar as imagens em cada pasta. Uma pasta = uma classe de planta

count=0
nomeplantas=[]
totalimagens=[]
for i in os.listdir(validpath):
  count+=1
  nomeplantas.append(i)
  
  images_path=os.listdir(validpath+"/"+i)
  totalimagens.append(len(images_path))

# %%
# Total de Classes de Plantas
len(nomeplantas)
# Out:
# 3

# %% [markdown]
# ## Tratar e  Carregar a Base de Treino
# ##### Ref: Como carregar imagens no Keras:
# https://www.tensorflow.org/tutorials/load_data/images
# ##### A documentação da função que usa para carregar os dados (detalhes dos parâmetros):
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

# %%
# A carga da imagem é feita em lotes o tamanho de lote ("batch_size") de 32 imagens
batch_size = 32
# altura da imagem
img_height = 224
# largura da imagem
img_width = 224

# %%
# usar a função para carregar as imagens:
# https://www.tensorflow.org/tutorials/load_data/images
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

train_data = tf.keras.utils.image_dataset_from_directory(   # função para carregar imagens de treino
  trainpath,                                                # caminho onde estão as imagens de treino (diretório "raiz")
  labels='inferred',                                        
  label_mode='categorical',                                          
  image_size=(img_height, img_width),                       # largura e altura
  batch_size=batch_size)                                    # tamanho do lote
# Out:
# Found 4659 files belonging to 3 classes.

# %%
# verifica o nome das classes (são 38 pastas, cada pasta é uma classe)
train_data.class_names
# Out:
# ['Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy']

# %%
# visualizar o tipo de objeto retornado
train_data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# loop para ver a dimensão da imagem:
# 32 classes (pastas)
# 250 largura
# 250 altura
# 3 canais
# obs: Um break para evitar de percorrer todas as imagens
for image_batch, labels_batch in train_data:
  print(image_batch.shape)
  break
# Out:
# (32, 224, 224, 3)

# %%
# Normalizar as imagens de treino para estabelecer uma variação de valores entre [0..1]. Camada específica para isso.
# Fonte: Documentação Keras

normalization_layer = tf.keras.layers.Rescaling(1./255)
train_data_normalized = train_data.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(train_data_normalized))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 0.0 0.97567034

# %%
# Analisa o resultado da normalização da Base de Treino
for image_batch, labels_batch in train_data_normalized:
  print(image_batch.shape)
  break
# Out:
# (32, 224, 224, 3)

# %%
# Analisa o resultado da normalização da Base de Treino - Formato
train_data_normalized
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# Analisa o resultado da normalização da Base de Treino - Matriz EGB
image_batch[5]
# Out:
# <tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
# array([[[0.81204486, 0.7571429 , 0.75322133],
#         [0.8209484 , 0.76604646, 0.7621249 ],
#         [0.82549024, 0.7705883 , 0.7666667 ],
#         ...,
#         [0.90906376, 0.8698481 , 0.86200494],
#         [0.922189  , 0.8829733 , 0.8751302 ],
#         [0.931933  , 0.8927173 , 0.88487417]],
#
#        [[0.8067227 , 0.75182074, 0.7478992 ],
#         [0.814846  , 0.75994396, 0.7560224 ],
#         [0.81682676, 0.7619248 , 0.75800323],
#         ...,
#         [0.90254116, 0.8633255 , 0.85548234],
#         [0.90988404, 0.87066835, 0.8628252 ],
#         [0.916927  , 0.8777113 , 0.86986816]],
#
#        [[0.7990596 , 0.7441577 , 0.7402361 ],
#         [0.8061825 , 0.75128055, 0.747359  ],
#         [0.81086445, 0.7559625 , 0.75204086],
#         ...,
#         [0.90016013, 0.86094445, 0.8531013 ],
#         [0.89945984, 0.86024415, 0.852401  ],
#         [0.8991597 , 0.85994405, 0.8521009 ]],
#
#        ...,
#
#        [[0.5807523 , 0.49839935, 0.4787915 ],
#         [0.56494606, 0.4825931 , 0.46298525],
#         [0.5574832 , 0.4751302 , 0.45552236],
#         ...,
#         [0.58673483, 0.50830346, 0.5043819 ],
#         [0.58977574, 0.5113444 , 0.5074228 ],
#         [0.5870743 , 0.5086429 , 0.50472134]],
#
#        [[0.5678871 , 0.48553416, 0.46592632],
#         [0.5658463 , 0.48349342, 0.46388558],
#         [0.5705483 , 0.4881954 , 0.46858755],
#         ...,
#         [0.6106845 , 0.53225315, 0.5283316 ],
#         [0.60914385, 0.5307125 , 0.5267909 ],
#         [0.5914765 , 0.5130451 , 0.5091235 ]],
#
#        [[0.5251693 , 0.44281644, 0.4232086 ],
#         [0.5351135 , 0.45276058, 0.43315274],
#         [0.5522806 , 0.4699276 , 0.45031977],
#         ...,
#         [0.56660604, 0.48817465, 0.48425308],
#         [0.5928569 , 0.5144255 , 0.51050395],
#         [0.592797  , 0.5143656 , 0.51044405]]], dtype=float32)>

# %% [markdown]
# ## Tratar e  Carregar a Base de Validação
# ## Ref: Como carregar imagens no Keras:
# https://www.tensorflow.org/tutorials/load_data/images
# ## A documentação da função que usa para carregar os dados (detalhes dos parâmetros):
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

# %%
# A carga da imagem é feita em lotes o tamanho de lote ("batch_size") de 32 imagens
batch_size = 32
# altura da imagem
img_height = 224
# largura da imagem
img_width = 224

# %%
trainpath
# Out:
# '/content/drive/MyDrive/TrabalhoFinal/DadosTCC/archive/classeuva/Train'

# %%
testpath
# Out:
# '/content/drive/MyDrive/TrabalhoFinal/DadosTCC/archive/classeuva/Test'

# %%
validpath
# Out:
# '/content/drive/MyDrive/TrabalhoFinal/DadosTCC/archive/classeuva/Valid'

# %%
# usar a função para carregar as imagens:
# https://www.tensorflow.org/tutorials/load_data/images
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

valid_data = tf.keras.utils.image_dataset_from_directory(   # função para carregar imagens de validação
  validpath,                                                # caminho onde estão as imagens de vaçidção (diretório "raiz")
  labels='inferred',                                        
  label_mode='categorical',                                 
  image_size=(img_height, img_width),                       # largura e altura
  batch_size=batch_size)                                    # tamanho do lote
# Out:
# Found 1169 files belonging to 3 classes.

# %%
# verifica o nome das classes (são 38 pastas, cada pasta é uma classe)
valid_data.class_names
# Out:
# ['Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy']

# %%
# visualizar o tipo de objeto retornado
valid_data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# loop para ver a dimensão da imagem:
# 32 classes (pastas)
# 250 largura
# 250 altura
# 3 canais
# obs: Um break para evitar de percorrer todas as imagens
for image_batch, labels_batch in valid_data:
  print(image_batch.shape)
  break
# Out:
# (32, 224, 224, 3)

# %%
# Normalizar as imagens de validação para estabelecer uma variação de valores entre [0..1]. Camada específica para isso.
# Fonte: Documentação Keras

normalization_layer = tf.keras.layers.Rescaling(1./255)
valid_data_normalized = valid_data.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(valid_data_normalized))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0039616656 0.96096534

# %%
# Analisa o resultado da normalização da Base de Validação
for image_batch, labels_batch in valid_data_normalized:
  print(image_batch.shape)
  break
# Out:
# (32, 224, 224, 3)

# %%
# Analisa o resultado da normalização da Base de Validação - Formato
valid_data_normalized
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# Analisa o resultado da normalização da Base de Validação - Matriz EGB
image_batch[2]
# Out:
# <tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
# array([[[0.07180875, 0.05272111, 0.07965188],
#         [0.7234294 , 0.70382154, 0.7312725 ],
#         [0.64988   , 0.63027215, 0.6577231 ],
#         ...,
#         [0.55818284, 0.5346534 , 0.5503397 ],
#         [0.48571384, 0.46218443, 0.4778707 ],
#         [0.43417302, 0.4106436 , 0.42632988]],
#
#        [[0.06912767, 0.05524212, 0.07697081],
#         [0.61082435, 0.5912165 , 0.6186675 ],
#         [0.669928  , 0.6503202 , 0.67777115],
#         ...,
#         [0.5588629 , 0.5353335 , 0.5510198 ],
#         [0.48385313, 0.4603237 , 0.47601   ],
#         [0.43327266, 0.40974325, 0.42542952]],
#
#        [[0.09737896, 0.08037216, 0.10522211],
#         [0.6041217 , 0.58451384, 0.6119648 ],
#         [0.6707284 , 0.6511205 , 0.6785715 ],
#         ...,
#         [0.54391694, 0.52038753, 0.5360738 ],
#         [0.47082794, 0.44729853, 0.4629848 ],
#         [0.42436916, 0.40083975, 0.41652602]],
#
#        ...,
#
#        [[0.06180475, 0.04527813, 0.06180475],
#         [0.65798324, 0.63053226, 0.65798324],
#         [0.6447579 , 0.61730695, 0.6447579 ],
#         ...,
#         [0.6593441 , 0.6162068 , 0.6318931 ],
#         [0.667468  , 0.62433076, 0.64001703],
#         [0.6805324 , 0.63739514, 0.6530814 ]],
#
#        [[0.06256505, 0.04603845, 0.06256505],
#         [0.6699481 , 0.6424971 , 0.6699481 ],
#         [0.66326547, 0.6358145 , 0.66326547],
#         ...,
#         [0.66904795, 0.6259107 , 0.641597  ],
#         [0.689836  , 0.6466988 , 0.66238505],
#         [0.64791816, 0.6047809 , 0.6204672 ]],
#
#        [[0.06690685, 0.04699883, 0.06690685],
#         [0.68531436, 0.6578634 , 0.68531436],
#         [0.688876  , 0.661425  , 0.688876  ],
#         ...,
#         [0.5933357 , 0.55019844, 0.5658847 ],
#         [0.59019434, 0.54705703, 0.56274337],
#         [0.5814713 , 0.5383341 , 0.55402035]]], dtype=float32)>

# %% [markdown]
# ## Resumo Leitura de Imagens
# ##### 53655 .. 80% testes, 13414 .. 20% validação e 67.069 total de imagens

# %% [markdown]
# ## Modelo de Classificação VGG19 sem Transfer Learning e Data Augmentation
# ##### Analisar a resposta da classificação

# %%
pip install tf-explain
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tf-explain
#   Downloading tf_explain-0.3.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 4.1 MB/s eta 0:00:00
# Installing collected packages: tf-explain
# Successfully installed tf-explain-0.3.1

# %%
## Código consultado em https://medium.com/analytics-vidhya/image-recognition-using-pre-trained-xception-model-in-5-steps-96ac858f4206

# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
# from tensorflow.keras.optmizers import Adam
# from tensorflow.keras.losses import CategoricalCrossentropy
# import numpy as np

model = tf.keras.applications.VGG19(weights='imagenet', input_shape=(img_height,img_width,3))

# Carrega uma imagem de uma classe (Treino) para verificar a predição nessa Rede, nessas condições.
img = image.load_img(trainpath+"/Grape___healthy/ac753212-e6d7-44b9-9722-4413a7418ab3___Mt.N.V_HL 6178_180deg.JPG", target_size=(img_height,img_width,3))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=4)[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574710816/574710816 [==============================] - 4s 0us/step
# 1/1 [==============================] - 12s 12s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n03991062', 'pot', 0.2972955), ('n12768682', 'buckeye', 0.10490957), ('n04522168', 'vase', 0.08454256), ('n12267677', 'acorn', 0.04454502)]

# %%
# Avaliação da assertividade para a classe Tomato___Tomato_mosaic_virus da base de treino
import matplotlib.pylab as plt
plt.imshow(img)

# %% [markdown]
# Modelo nessa condição não obteve sucesso na identificação de uma imagem de uma classe. O que era previsto somente comprovando a necessidade de treinar um modelo aplicando Transfer Learning.

# %%
# Visualização das Camadas do Modelo VGG19 sem Transfer Learning e Data Augmentation
model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Analisa Camadas VGG19 Truncada

# %%
base_model_tf=tf.keras.applications.VGG19(weights='imagenet', classes=3, input_shape=(img_height,img_width,3), include_top=False)

#Model building
base_model_tf.trainable=False

base_model_tf.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
## API Keras https://keras.io/guides/functional_api/
## https://keras.io/guides/sequential_model/

# %% [markdown]
# ## Modelo VGG19 Base para Aplicar Transfer Learning

# %%
# Modelo Truncado:
modelo_base = tf.keras.applications.VGG19(weights='imagenet', classes=3, input_shape=(img_height,img_width,3), include_top=False)
# "Congelar" as camadas superiores (manter os pesos):
modelo_base.trainable=False
modelo_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ## Modelo VGG19 Truncado + Camada Dense
#
# *   Aproveitar a base de conhecimento VGG19 (Imagenet) e seus pesos
# *   Treinar essa base adicionando as novas Classes de Treino das Imagens Coletadas

# %%
# from tensorflow.keras.layers import Flatten
sh=Input(shape=(img_height,img_width,3)) # Formato de entrada imagem
conv=tf.cast(sh,tf.float32) 

modelo_dense_1=modelo_base(conv,training=False) #
modelo_dense_1=Dropout(0.2)(modelo_dense_1)
modelo_dense_1=GlobalAveragePooling2D()(modelo_dense_1)
modelo_dense_1=ks.layers.BatchNormalization(axis=1, momentum=0.99, epsilon=0.001)(modelo_dense_1)
modelo_dense_1=Dense(128,activation='relu')(modelo_dense_1)
modelo_dense_1=Dense(64,activation='relu')(modelo_dense_1)
modelo_dense_1=Dense(3,activation='softmax')(modelo_dense_1)

from keras.models import Model
modelo_final_1=Model(inputs=sh,outputs=modelo_dense_1)
modelo_final_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.cast (TFOpLambda)        (None, 224, 224, 3)       0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  dropout (Dropout)           (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 20,100,547
# Trainable params: 75,139
# Non-trainable params: 20,025,408
# _________________________________________________________________

# %%
modelo_final_1.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f9111348040>,
#  <keras.layers.core.tf_op_layer.TFOpLambda at 0x7f91113beaf0>,
#  <keras.engine.functional.Functional at 0x7f9111333ac0>,
#  <keras.layers.regularization.dropout.Dropout at 0x7f911137b130>,
#  <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7f9111348340>,
#  <keras.layers.normalization.batch_normalization.BatchNormalization at 0x7f911134c130>,
#  <keras.layers.core.dense.Dense at 0x7f91112d96a0>,
#  <keras.layers.core.dense.Dense at 0x7f91112e8910>,
#  <keras.layers.core.dense.Dense at 0x7f91112f66a0>]

# %%
# Definie as métricas
earlystp=EarlyStopping(patience=25, monitor='val_loss') # Evitar um Overfiting do Modelo
metrics = ['accuracy',Precision(),Recall(), AUC()]

# %%
# Compila o Modelo
modelo_final_1.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01),metrics=metrics)

# %%
# Processa o modelo com Transfer Learning usando a base de imagens de Treino Normalizada e a base de Validação Normalizada
modelo_final_1_Hist = modelo_final_1.fit(train_data_normalized,validation_data=valid_data_normalized,epochs=200,verbose=1,callbacks=[earlystp])
# Out:
# Epoch 1/200
# 146/146 [==============================] - 791s 5s/step - loss: 0.2214 - accuracy: 0.9221 - precision: 0.9244 - recall: 0.9191 - auc: 0.9856 - val_loss: 0.3740 - val_accuracy: 0.8905 - val_precision: 0.9340 - val_recall: 0.8238 - val_auc: 0.9842
# Epoch 2/200
# 146/146 [==============================] - 37s 253ms/step - loss: 0.1167 - accuracy: 0.9551 - precision: 0.9570 - recall: 0.9547 - auc: 0.9951 - val_loss: 0.2191 - val_accuracy: 0.9461 - val_precision: 0.9676 - val_recall: 0.9196 - val_auc: 0.9955
# Epoch 3/200
# 146/146 [==============================] - 39s 265ms/step - loss: 0.0984 - accuracy: 0.9629 - precision: 0.9628 - recall: 0.9616 - auc: 0.9968 - val_loss: 0.1026 - val_accuracy: 0.9632 - val_precision: 0.9639 - val_recall: 0.9607 - val_auc: 0.9976
# Epoch 4/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0947 - accuracy: 0.9663 - precision: 0.9669 - recall: 0.9657 - auc: 0.9969 - val_loss: 0.0933 - val_accuracy: 0.9675 - val_precision: 0.9674 - val_recall: 0.9658 - val_auc: 0.9974
# Epoch 5/200
# 146/146 [==============================] - 39s 266ms/step - loss: 0.0751 - accuracy: 0.9706 - precision: 0.9716 - recall: 0.9704 - auc: 0.9977 - val_loss: 0.0835 - val_accuracy: 0.9709 - val_precision: 0.9709 - val_recall: 0.9709 - val_auc: 0.9973
# Epoch 6/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.1087 - accuracy: 0.9652 - precision: 0.9664 - recall: 0.9642 - auc: 0.9961 - val_loss: 0.0789 - val_accuracy: 0.9658 - val_precision: 0.9658 - val_recall: 0.9649 - val_auc: 0.9983
# Epoch 7/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0805 - accuracy: 0.9708 - precision: 0.9725 - recall: 0.9704 - auc: 0.9975 - val_loss: 0.1218 - val_accuracy: 0.9589 - val_precision: 0.9597 - val_recall: 0.9581 - val_auc: 0.9937
# Epoch 8/200
# 146/146 [==============================] - 39s 265ms/step - loss: 0.0762 - accuracy: 0.9760 - precision: 0.9766 - recall: 0.9745 - auc: 0.9977 - val_loss: 0.0977 - val_accuracy: 0.9683 - val_precision: 0.9683 - val_recall: 0.9666 - val_auc: 0.9961
# Epoch 9/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0490 - accuracy: 0.9815 - precision: 0.9822 - recall: 0.9811 - auc: 0.9990 - val_loss: 0.0770 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9970
# Epoch 10/200
# 146/146 [==============================] - 36s 241ms/step - loss: 0.0539 - accuracy: 0.9809 - precision: 0.9813 - recall: 0.9805 - auc: 0.9987 - val_loss: 0.0758 - val_accuracy: 0.9735 - val_precision: 0.9735 - val_recall: 0.9726 - val_auc: 0.9969
# Epoch 11/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0422 - accuracy: 0.9843 - precision: 0.9852 - recall: 0.9837 - auc: 0.9991 - val_loss: 0.0957 - val_accuracy: 0.9735 - val_precision: 0.9743 - val_recall: 0.9726 - val_auc: 0.9944
# Epoch 12/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0564 - accuracy: 0.9843 - precision: 0.9845 - recall: 0.9839 - auc: 0.9986 - val_loss: 0.1069 - val_accuracy: 0.9701 - val_precision: 0.9701 - val_recall: 0.9701 - val_auc: 0.9948
# Epoch 13/200
# 146/146 [==============================] - 36s 240ms/step - loss: 0.0520 - accuracy: 0.9841 - precision: 0.9845 - recall: 0.9837 - auc: 0.9987 - val_loss: 0.1258 - val_accuracy: 0.9709 - val_precision: 0.9709 - val_recall: 0.9709 - val_auc: 0.9918
# Epoch 14/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.1021 - accuracy: 0.9734 - precision: 0.9744 - recall: 0.9730 - auc: 0.9957 - val_loss: 0.1505 - val_accuracy: 0.9615 - val_precision: 0.9614 - val_recall: 0.9598 - val_auc: 0.9893
# Epoch 15/200
# 146/146 [==============================] - 39s 266ms/step - loss: 0.0525 - accuracy: 0.9828 - precision: 0.9843 - recall: 0.9824 - auc: 0.9985 - val_loss: 0.0869 - val_accuracy: 0.9701 - val_precision: 0.9699 - val_recall: 0.9649 - val_auc: 0.9978
# Epoch 16/200
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0528 - accuracy: 0.9822 - precision: 0.9836 - recall: 0.9807 - auc: 0.9986 - val_loss: 0.1481 - val_accuracy: 0.9530 - val_precision: 0.9552 - val_recall: 0.9495 - val_auc: 0.9926
# Epoch 17/200
# 146/146 [==============================] - 39s 265ms/step - loss: 0.0459 - accuracy: 0.9837 - precision: 0.9854 - recall: 0.9824 - auc: 0.9990 - val_loss: 0.0793 - val_accuracy: 0.9795 - val_precision: 0.9794 - val_recall: 0.9778 - val_auc: 0.9972
# Epoch 18/200
# 146/146 [==============================] - 39s 265ms/step - loss: 0.0427 - accuracy: 0.9856 - precision: 0.9858 - recall: 0.9841 - auc: 0.9988 - val_loss: 0.0831 - val_accuracy: 0.9735 - val_precision: 0.9743 - val_recall: 0.9735 - val_auc: 0.9968
# Epoch 19/200
# 146/146 [==============================] - 39s 265ms/step - loss: 0.0273 - accuracy: 0.9927 - precision: 0.9929 - recall: 0.9921 - auc: 0.9995 - val_loss: 0.1280 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9918
# Epoch 20/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0284 - accuracy: 0.9906 - precision: 0.9908 - recall: 0.9903 - auc: 0.9996 - val_loss: 0.1392 - val_accuracy: 0.9666 - val_precision: 0.9666 - val_recall: 0.9658 - val_auc: 0.9927
# Epoch 21/200
# 146/146 [==============================] - 39s 266ms/step - loss: 0.0317 - accuracy: 0.9893 - precision: 0.9895 - recall: 0.9893 - auc: 0.9991 - val_loss: 0.1407 - val_accuracy: 0.9649 - val_precision: 0.9665 - val_recall: 0.9632 - val_auc: 0.9933
# Epoch 22/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0313 - accuracy: 0.9910 - precision: 0.9914 - recall: 0.9906 - auc: 0.9992 - val_loss: 0.1053 - val_accuracy: 0.9778 - val_precision: 0.9778 - val_recall: 0.9778 - val_auc: 0.9941
# Epoch 23/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0454 - accuracy: 0.9873 - precision: 0.9880 - recall: 0.9867 - auc: 0.9984 - val_loss: 0.1371 - val_accuracy: 0.9701 - val_precision: 0.9701 - val_recall: 0.9701 - val_auc: 0.9925
# Epoch 24/200
# 146/146 [==============================] - 36s 241ms/step - loss: 0.0514 - accuracy: 0.9865 - precision: 0.9865 - recall: 0.9858 - auc: 0.9984 - val_loss: 0.0846 - val_accuracy: 0.9812 - val_precision: 0.9829 - val_recall: 0.9812 - val_auc: 0.9968
# Epoch 25/200
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0854 - accuracy: 0.9790 - precision: 0.9792 - recall: 0.9788 - auc: 0.9967 - val_loss: 0.1012 - val_accuracy: 0.9624 - val_precision: 0.9623 - val_recall: 0.9598 - val_auc: 0.9967
# Epoch 26/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0492 - accuracy: 0.9839 - precision: 0.9843 - recall: 0.9837 - auc: 0.9988 - val_loss: 0.0814 - val_accuracy: 0.9735 - val_precision: 0.9743 - val_recall: 0.9726 - val_auc: 0.9952
# Epoch 27/200
# 146/146 [==============================] - 36s 243ms/step - loss: 0.0406 - accuracy: 0.9860 - precision: 0.9860 - recall: 0.9860 - auc: 0.9990 - val_loss: 0.0884 - val_accuracy: 0.9769 - val_precision: 0.9769 - val_recall: 0.9760 - val_auc: 0.9969
# Epoch 28/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0239 - accuracy: 0.9912 - precision: 0.9916 - recall: 0.9906 - auc: 0.9994 - val_loss: 0.1049 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9936
# Epoch 29/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0415 - accuracy: 0.9878 - precision: 0.9880 - recall: 0.9878 - auc: 0.9987 - val_loss: 0.0758 - val_accuracy: 0.9769 - val_precision: 0.9769 - val_recall: 0.9760 - val_auc: 0.9964
# Epoch 30/200
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0269 - accuracy: 0.9899 - precision: 0.9901 - recall: 0.9895 - auc: 0.9993 - val_loss: 0.1396 - val_accuracy: 0.9683 - val_precision: 0.9692 - val_recall: 0.9683 - val_auc: 0.9921
# Epoch 31/200
# 146/146 [==============================] - 36s 240ms/step - loss: 0.0226 - accuracy: 0.9923 - precision: 0.9923 - recall: 0.9923 - auc: 0.9995 - val_loss: 0.1188 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9946
# Epoch 32/200
# 146/146 [==============================] - 40s 264ms/step - loss: 0.0163 - accuracy: 0.9944 - precision: 0.9944 - recall: 0.9944 - auc: 0.9998 - val_loss: 0.1125 - val_accuracy: 0.9692 - val_precision: 0.9692 - val_recall: 0.9683 - val_auc: 0.9954
# Epoch 33/200
# 146/146 [==============================] - 36s 242ms/step - loss: 0.0812 - accuracy: 0.9833 - precision: 0.9833 - recall: 0.9830 - auc: 0.9980 - val_loss: 0.1229 - val_accuracy: 0.9726 - val_precision: 0.9726 - val_recall: 0.9726 - val_auc: 0.9940
# Epoch 34/200
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0355 - accuracy: 0.9869 - precision: 0.9880 - recall: 0.9865 - auc: 0.9989 - val_loss: 0.0770 - val_accuracy: 0.9778 - val_precision: 0.9778 - val_recall: 0.9778 - val_auc: 0.9979
# Epoch 35/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0281 - accuracy: 0.9908 - precision: 0.9912 - recall: 0.9908 - auc: 0.9993 - val_loss: 0.0917 - val_accuracy: 0.9692 - val_precision: 0.9700 - val_recall: 0.9692 - val_auc: 0.9960
# Epoch 36/200
# 146/146 [==============================] - 36s 240ms/step - loss: 0.0468 - accuracy: 0.9895 - precision: 0.9895 - recall: 0.9891 - auc: 0.9990 - val_loss: 0.1377 - val_accuracy: 0.9641 - val_precision: 0.9640 - val_recall: 0.9632 - val_auc: 0.9937
# Epoch 37/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0589 - accuracy: 0.9863 - precision: 0.9863 - recall: 0.9863 - auc: 0.9978 - val_loss: 0.1222 - val_accuracy: 0.9701 - val_precision: 0.9708 - val_recall: 0.9683 - val_auc: 0.9934
# Epoch 38/200
# 146/146 [==============================] - 36s 241ms/step - loss: 0.0275 - accuracy: 0.9923 - precision: 0.9923 - recall: 0.9923 - auc: 0.9992 - val_loss: 0.0771 - val_accuracy: 0.9795 - val_precision: 0.9795 - val_recall: 0.9795 - val_auc: 0.9964
# Epoch 39/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0304 - accuracy: 0.9910 - precision: 0.9910 - recall: 0.9910 - auc: 0.9990 - val_loss: 0.1084 - val_accuracy: 0.9726 - val_precision: 0.9726 - val_recall: 0.9726 - val_auc: 0.9948
# Epoch 40/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0253 - accuracy: 0.9923 - precision: 0.9923 - recall: 0.9918 - auc: 0.9994 - val_loss: 0.0912 - val_accuracy: 0.9786 - val_precision: 0.9786 - val_recall: 0.9778 - val_auc: 0.9952
# Epoch 41/200
# 146/146 [==============================] - 39s 265ms/step - loss: 0.0235 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9933 - auc: 0.9992 - val_loss: 0.0917 - val_accuracy: 0.9743 - val_precision: 0.9743 - val_recall: 0.9743 - val_auc: 0.9953
# Epoch 42/200
# 146/146 [==============================] - 39s 265ms/step - loss: 0.0246 - accuracy: 0.9938 - precision: 0.9940 - recall: 0.9938 - auc: 0.9992 - val_loss: 0.1709 - val_accuracy: 0.9701 - val_precision: 0.9701 - val_recall: 0.9701 - val_auc: 0.9893
# Epoch 43/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0287 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9992 - val_loss: 0.1205 - val_accuracy: 0.9709 - val_precision: 0.9709 - val_recall: 0.9709 - val_auc: 0.9949
# Epoch 44/200
# 146/146 [==============================] - 39s 265ms/step - loss: 0.0414 - accuracy: 0.9897 - precision: 0.9901 - recall: 0.9897 - auc: 0.9989 - val_loss: 0.1209 - val_accuracy: 0.9709 - val_precision: 0.9709 - val_recall: 0.9709 - val_auc: 0.9930
# Epoch 45/200
# 146/146 [==============================] - 36s 241ms/step - loss: 0.0740 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - auc: 0.9985 - val_loss: 0.1414 - val_accuracy: 0.9658 - val_precision: 0.9658 - val_recall: 0.9658 - val_auc: 0.9934
# Epoch 46/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0439 - accuracy: 0.9884 - precision: 0.9888 - recall: 0.9882 - auc: 0.9987 - val_loss: 0.1646 - val_accuracy: 0.9658 - val_precision: 0.9666 - val_recall: 0.9658 - val_auc: 0.9896
# Epoch 47/200
# 146/146 [==============================] - 36s 240ms/step - loss: 0.0359 - accuracy: 0.9888 - precision: 0.9890 - recall: 0.9886 - auc: 0.9988 - val_loss: 0.1657 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9935
# Epoch 48/200
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0198 - accuracy: 0.9921 - precision: 0.9921 - recall: 0.9916 - auc: 0.9997 - val_loss: 0.1318 - val_accuracy: 0.9743 - val_precision: 0.9743 - val_recall: 0.9743 - val_auc: 0.9932
# Epoch 49/200
# 146/146 [==============================] - 39s 264ms/step - loss: 0.0389 - accuracy: 0.9923 - precision: 0.9925 - recall: 0.9923 - auc: 0.9989 - val_loss: 0.1141 - val_accuracy: 0.9581 - val_precision: 0.9581 - val_recall: 0.9581 - val_auc: 0.9948
# Epoch 50/200
# 146/146 [==============================] - 39s 266ms/step - loss: 0.0353 - accuracy: 0.9901 - precision: 0.9908 - recall: 0.9901 - auc: 0.9991 - val_loss: 0.1381 - val_accuracy: 0.9726 - val_precision: 0.9735 - val_recall: 0.9726 - val_auc: 0.9929
# Epoch 51/200
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0543 - accuracy: 0.9897 - precision: 0.9897 - recall: 0.9895 - auc: 0.9988 - val_loss: 0.1458 - val_accuracy: 0.9692 - val_precision: 0.9709 - val_recall: 0.9692 - val_auc: 0.9922
# Epoch 52/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0315 - accuracy: 0.9914 - precision: 0.9916 - recall: 0.9914 - auc: 0.9993 - val_loss: 0.0971 - val_accuracy: 0.9735 - val_precision: 0.9743 - val_recall: 0.9735 - val_auc: 0.9963
# Epoch 53/200
# 146/146 [==============================] - 36s 240ms/step - loss: 0.0684 - accuracy: 0.9865 - precision: 0.9869 - recall: 0.9865 - auc: 0.9973 - val_loss: 0.1257 - val_accuracy: 0.9743 - val_precision: 0.9743 - val_recall: 0.9743 - val_auc: 0.9936
# Epoch 54/200
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0935 - accuracy: 0.9863 - precision: 0.9865 - recall: 0.9863 - auc: 0.9972 - val_loss: 0.1416 - val_accuracy: 0.9726 - val_precision: 0.9726 - val_recall: 0.9726 - val_auc: 0.9922

# %%
modelo_final_1.save('/content/drive/MyDrive/TrabalhoFinal/DadosTCC/archive/Inferência-TestesModelos/Caso de Teste 04/VGG19-cenário06/Modelo_Salvo_1/VGG19.h5')

# %%
from datetime import datetime
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2023, 3, 1, 18, 39, 7, 981797)

# %% [markdown]
# ## Análise da VGG19 - Transfer Learning
# ##### Métricas:
# ###### Acurácia: Taxa de acerto do modelo - VP + VN / (VP+VN+FN+FP). Pode mascarar falso positivo e falso negativo.
# ###### Recall: Taxa de VP entre todas as classes positivas. Varia de 0 a 1 , quanto maior o valor melhor - VP / VP + FN
# ###### Precisão: Taxa de VP entre os valores Positivos Preditos. VP / VP+FP. Quanto menor a qtd de falsos alarmes melhor.
# ###### AUC: Relação com a curva ROC (Receiver Operating Characteristic). É a área sob a curva e é recomendada para comparar modelos diferentes. Varia entre 0 e 1 e quanto maior o valor melhor a classificação.

# %%
print(modelo_final_1_Hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'auc', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc'])

# %%
plt.plot(modelo_final_1_Hist.history['accuracy'])
plt.plot(modelo_final_1_Hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(modelo_final_1_Hist.history['loss'])
plt.plot(modelo_final_1_Hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(modelo_final_1_Hist.history['precision'])
plt.plot(modelo_final_1_Hist.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(modelo_final_1_Hist.history['recall'])
plt.plot(modelo_final_1_Hist.history['val_recall'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(modelo_final_1_Hist.history['auc'])
plt.plot(modelo_final_1_Hist.history['val_auc'])
plt.title('model auc')
plt.ylabel('auc')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()
